# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Polygon

# %%
import seaborn as sns

# %%
DF= pd.read_csv("C:/Users/WeiKuang/Desktop/BioStat Spring 2018/141C/141C Final Project/train.csv")
DF.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#len(DF.Alley[isinstance(DF.Alley.values,float)])
isinstance(DF.Alley.values[0],float)
# Out:
# True

# %%
d
str(DF["Alley"][d]) == "nan"
type(DF["Alley"][d])
# Out:
# str

# %%
for d in range(len(DF["Alley"])):
    if str(DF["Alley"][d]) == "nan":
        DF["Alley"][d] = "NoAccess"
# Out:
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sns.boxplot(x=DF["Alley"], y=DF["SalePrice"], data= DF)
plt.show()
# Out:
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\seaborn\categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
#for d in range(len(DF["Alley"])):
#    if isinstance(DF.Alley.values[d],float):
#        DF["Alley"][d] = "NoAccess"
        
        
    
sns.boxplot(x=DF["SaleCondition"], y=DF["SalePrice"], data= DF)
plt.show()
# Out:
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\seaborn\categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
np.average(pd.isnull(DF["Foundation"]))
# Out:
# 0.0

# %%
L = []
for c in range(DF.shape[1]):
    MP = np.average(pd.isnull(DF.iloc[:,c]))
    ColName = DF.columns[c]
    pair = ( ColName,  MP )
    L = L + [pair]

# %%
MissingPercentage= pd.DataFrame(L)
f, ax = plt.subplots(figsize=(6, 15))
sns.barplot(MissingPercentage.iloc[:,1],MissingPercentage.iloc[:,0] )
ax.set(xlim=(0, 1), ylabel="", xlabel="Missing value percentage")


plt.show()
# Out:
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
