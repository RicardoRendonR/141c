# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Polygon
import seaborn as sns

# %%
DF= pd.read_csv("C:/Users/WeiKuang/Documents/GitHub/141c/train.csv")
DF.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
#descriptive statistics summary
DF['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(DF['SalePrice'])
plt.show()

# %% [markdown]
# #### Correlation matrix (heatmap style)

# %%
corrmat = DF.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()

# %%
# Correlation between SalePrice and other variables
PriceCorr = pd.DataFrame( corrmat['SalePrice'] )
PriceCorr = PriceCorr.sort_values(by= ["SalePrice"], ascending=False)
PriceCorr = PriceCorr.reset_index()


# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))
#sns.set_color_codes("pastel")
sns.barplot(y = "index", x="SalePrice", data=PriceCorr, color="b")

ax.set(xlim=(-1.01, 1.01), ylabel="index", xlabel="Correlation Coefficient for SalePrice")
plt.show()
# Out:
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# ## Using Julia's code to do data conversion

# %%
DF= pd.read_csv("C:/Users/WeiKuang/Documents/GitHub/141c/train.csv")

# %%
DF.Street[DF.Street=="Pave"]  = pd.Series([2]*len(DF.Street[DF.Street=="Pave"])).values
# Out:
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
DF.Street[DF.Street=="Grvl"] = pd.Series([1]*len(DF.Street[DF.Street=="Grvl"])).values
# Out:
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
DF= pd.read_csv("C:/Users/WeiKuang/Documents/GitHub/141c/train.csv")

#### Julian's code ####
DF.Street[DF.Street=="Grvl"] = pd.Series([1]*len(DF.Street[DF.Street=="Grvl"])).values
DF.Street[DF.Street=="Pave"]  = pd.Series([2]*len(DF.Street[DF.Street=="Pave"])).values

DF.LotShape[DF.LotShape=="Reg"] = pd.Series([4]*len(DF.LotShape[DF.LotShape=="Reg"])).values
DF.LotShape[DF.LotShape=="IR1"]  = pd.Series([3]*len(DF.LotShape[DF.LotShape=="IR1"])).values
DF.LotShape[DF.LotShape=="IR2"]  = pd.Series([2]*len(DF.LotShape[DF.LotShape=="IR2"])).values
DF.LotShape[DF.LotShape=="IR3"]  = pd.Series([1]*len(DF.LotShape[DF.LotShape=="IR3"])).values

DF.Alley.fillna(0, inplace=True)
DF.Alley[DF.Alley=="Grvl"] = pd.Series([1]*len(DF.Alley[DF.Alley=="Grvl"])).values
DF.Alley[DF.Alley=="Pave"]  = pd.Series([2]*len(DF.Alley[DF.Alley=="Pave"])).values

DF.Utilities[DF.Utilities=="AllPub"] = pd.Series([4]*len(DF.Utilities[DF.Utilities=="AllPub"])).values
DF.Utilities[DF.Utilities=="NoSewr"]  = pd.Series([3]*len(DF.Utilities[DF.Utilities=="NoSewr"])).values
DF.Utilities[DF.Utilities=="NoSeWa"]  = pd.Series([2]*len(DF.Utilities[DF.Utilities=="NoSeWa"])).values
DF.Utilities[DF.Utilities=="ELO"]  = pd.Series([1]*len(DF.Utilities[DF.Utilities=="ELO"])).values

DF.HouseStyle[DF.HouseStyle=="1.5Unf"] = pd.Series([1.25]*len(DF.HouseStyle[DF.HouseStyle=="1.5Unf"])).values
DF.HouseStyle[DF.HouseStyle=="1.5Fin"]  = pd.Series([1.5]*len(DF.HouseStyle[DF.HouseStyle=="1.5Fin"])).values
DF.HouseStyle[DF.HouseStyle=="2Story"]  = pd.Series([2]*len(DF.HouseStyle[DF.HouseStyle=="2Story"])).values
DF.HouseStyle[DF.HouseStyle=="1Story"]  = pd.Series([1]*len(DF.HouseStyle[DF.HouseStyle=="1Story"])).values
DF.HouseStyle[DF.HouseStyle=="2.5Fin"] = pd.Series([2.5]*len(DF.HouseStyle[DF.HouseStyle=="2.5Fin"])).values
DF.HouseStyle[DF.HouseStyle=="2.5Unf"]  = pd.Series([2.25]*len(DF.HouseStyle[DF.HouseStyle=="2.5Unf"])).values
DF.HouseStyle[DF.HouseStyle=="SFoyer"]  = pd.Series([1.75]*len(DF.HouseStyle[DF.HouseStyle=="SFoyer"])).values
DF.HouseStyle[DF.HouseStyle=="SLvl"]  = pd.Series([1.75]*len(DF.HouseStyle[DF.HouseStyle=="SLvl"])).values

DF.ExterQual[DF.ExterQual=="Ex"] = pd.Series([4]*len(DF.ExterQual[DF.ExterQual=="Ex"])).values
DF.ExterQual[DF.ExterQual=="Gd"]  = pd.Series([3]*len(DF.ExterQual[DF.ExterQual=="Gd"])).values
DF.ExterQual[DF.ExterQual=="TA"]  = pd.Series([2]*len(DF.ExterQual[DF.ExterQual=="TA"])).values
DF.ExterQual[DF.ExterQual=="Fa"]  = pd.Series([1]*len(DF.ExterQual[DF.ExterQual=="Fa"])).values

DF.ExterCond[DF.ExterCond=="Ex"] = pd.Series([5]*len(DF.ExterCond[DF.ExterCond=="Ex"])).values
DF.ExterCond[DF.ExterCond=="Gd"]  = pd.Series([4]*len(DF.ExterCond[DF.ExterCond=="Gd"])).values
DF.ExterCond[DF.ExterCond=="TA"]  = pd.Series([3]*len(DF.ExterCond[DF.ExterCond=="TA"])).values
DF.ExterCond[DF.ExterCond=="Fa"]  = pd.Series([2]*len(DF.ExterCond[DF.ExterCond=="Fa"])).values
DF.ExterCond[DF.ExterCond=="Po"]  = pd.Series([1]*len(DF.ExterCond[DF.ExterCond=="Po"])).values

DF.BsmtQual[DF.BsmtQual=="Ex"] = pd.Series([4]*len(DF.BsmtQual[DF.BsmtQual=="Ex"])).values
DF.BsmtQual[DF.BsmtQual=="Gd"]  = pd.Series([3]*len(DF.BsmtQual[DF.BsmtQual=="Gd"])).values
DF.BsmtQual[DF.BsmtQual=="TA"]  = pd.Series([2]*len(DF.BsmtQual[DF.BsmtQual=="TA"])).values
DF.BsmtQual[DF.BsmtQual=="Fa"]  = pd.Series([1]*len(DF.BsmtQual[DF.BsmtQual=="Fa"])).values
DF.BsmtQual.fillna(0, inplace=True)

DF.BsmtCond[DF.BsmtCond=="Gd"]  = pd.Series([4]*len(DF.BsmtCond[DF.BsmtCond=="Gd"])).values
DF.BsmtCond[DF.BsmtCond=="TA"]  = pd.Series([3]*len(DF.BsmtCond[DF.BsmtCond=="TA"])).values
DF.BsmtCond[DF.BsmtCond=="Fa"]  = pd.Series([2]*len(DF.BsmtCond[DF.BsmtCond=="Fa"])).values
DF.BsmtCond[DF.BsmtCond=="Po"]  = pd.Series([1]*len(DF.BsmtCond[DF.BsmtCond=="Po"])).values
DF.BsmtCond.fillna(0, inplace=True)

DF.BsmtExposure[DF.BsmtExposure=="Gd"]  = pd.Series([4]*len(DF.BsmtExposure[DF.BsmtExposure=="Gd"])).values
DF.BsmtExposure[DF.BsmtExposure=="Av"]  = pd.Series([3]*len(DF.BsmtExposure[DF.BsmtExposure=="Av"])).values
DF.BsmtExposure[DF.BsmtExposure=="Mn"]  = pd.Series([2]*len(DF.BsmtExposure[DF.BsmtExposure=="Mn"])).values
DF.BsmtExposure[DF.BsmtExposure=="No"]  = pd.Series([1]*len(DF.BsmtExposure[DF.BsmtExposure=="No"])).values
DF.BsmtExposure.fillna(0, inplace=True)

DF.BsmtFinType1[DF.BsmtFinType1=="GLQ"]  = pd.Series([6]*len(DF.BsmtFinType1[DF.BsmtFinType1=="GLQ"])).values
DF.BsmtFinType1[DF.BsmtFinType1=="ALQ"]  = pd.Series([5]*len(DF.BsmtFinType1[DF.BsmtFinType1=="ALQ"])).values
DF.BsmtFinType1[DF.BsmtFinType1=="BLQ"]  = pd.Series([4]*len(DF.BsmtFinType1[DF.BsmtFinType1=="BLQ"])).values
DF.BsmtFinType1[DF.BsmtFinType1=="Rec"]  = pd.Series([3]*len(DF.BsmtFinType1[DF.BsmtFinType1=="Rec"])).values
DF.BsmtFinType1[DF.BsmtFinType1=="LwQ"]  = pd.Series([2]*len(DF.BsmtFinType1[DF.BsmtFinType1=="LwQ"])).values
DF.BsmtFinType1[DF.BsmtFinType1=="Unf"]  = pd.Series([1]*len(DF.BsmtFinType1[DF.BsmtFinType1=="Unf"])).values
DF.BsmtFinType1.fillna(0, inplace=True)

DF.BsmtFinType2[DF.BsmtFinType2=="GLQ"]  = pd.Series([6]*len(DF.BsmtFinType2[DF.BsmtFinType2=="GLQ"])).values
DF.BsmtFinType2[DF.BsmtFinType2=="ALQ"]  = pd.Series([5]*len(DF.BsmtFinType2[DF.BsmtFinType2=="ALQ"])).values
DF.BsmtFinType2[DF.BsmtFinType2=="BLQ"]  = pd.Series([4]*len(DF.BsmtFinType2[DF.BsmtFinType2=="BLQ"])).values
DF.BsmtFinType2[DF.BsmtFinType2=="Rec"]  = pd.Series([3]*len(DF.BsmtFinType2[DF.BsmtFinType2=="Rec"])).values
DF.BsmtFinType2[DF.BsmtFinType2=="LwQ"]  = pd.Series([2]*len(DF.BsmtFinType2[DF.BsmtFinType2=="LwQ"])).values
DF.BsmtFinType2[DF.BsmtFinType2=="Unf"]  = pd.Series([1]*len(DF.BsmtFinType2[DF.BsmtFinType2=="Unf"])).values
DF.BsmtFinType2.fillna(0, inplace=True)

DF.HeatingQC[DF.HeatingQC=="Ex"] = pd.Series([5]*len(DF.HeatingQC[DF.HeatingQC=="Ex"])).values
DF.HeatingQC[DF.HeatingQC=="Gd"]  = pd.Series([4]*len(DF.HeatingQC[DF.HeatingQC=="Gd"])).values
DF.HeatingQC[DF.HeatingQC=="TA"]  = pd.Series([3]*len(DF.HeatingQC[DF.HeatingQC=="TA"])).values
DF.HeatingQC[DF.HeatingQC=="Fa"]  = pd.Series([2]*len(DF.HeatingQC[DF.HeatingQC=="Fa"])).values
DF.HeatingQC[DF.HeatingQC=="Po"]  = pd.Series([1]*len(DF.HeatingQC[DF.HeatingQC=="Po"])).values

DF.CentralAir[DF.CentralAir=="Yes"] = pd.Series([1]*len(DF.CentralAir[DF.CentralAir=="Yes"])).values
DF.CentralAir[DF.CentralAir=="No"]  = pd.Series([0]*len(DF.CentralAir[DF.CentralAir=="No"])).values

DF.KitchenQual[DF.KitchenQual=="Ex"] = pd.Series([5]*len(DF.KitchenQual[DF.KitchenQual=="Ex"])).values
DF.KitchenQual[DF.KitchenQual=="Gd"]  = pd.Series([4]*len(DF.KitchenQual[DF.KitchenQual=="Gd"])).values
DF.KitchenQual[DF.KitchenQual=="TA"]  = pd.Series([3]*len(DF.KitchenQual[DF.KitchenQual=="TA"])).values
DF.KitchenQual[DF.KitchenQual=="Fa"]  = pd.Series([2]*len(DF.KitchenQual[DF.KitchenQual=="Fa"])).values
DF.KitchenQual[DF.KitchenQual=="Po"]  = pd.Series([1]*len(DF.KitchenQual[DF.KitchenQual=="Po"])).values

DF.Functional[DF.Functional=="Typ"] = pd.Series([7]*len(DF.Functional[DF.Functional=="Typ"])).values
DF.Functional[DF.Functional=="Min1"]  = pd.Series([6]*len(DF.Functional[DF.Functional=="Min1"])).values
DF.Functional[DF.Functional=="Min2"] = pd.Series([5]*len(DF.Functional[DF.Functional=="Min2"])).values
DF.Functional[DF.Functional=="Mod"]  = pd.Series([4]*len(DF.Functional[DF.Functional=="Mod"])).values
DF.Functional[DF.Functional=="Maj1"]  = pd.Series([3]*len(DF.Functional[DF.Functional=="Maj1"])).values
DF.Functional[DF.Functional=="Maj2"]  = pd.Series([2]*len(DF.Functional[DF.Functional=="Maj2"])).values
DF.Functional[DF.Functional=="Sev"]  = pd.Series([1]*len(DF.Functional[DF.Functional=="Sev"])).values
DF.Functional[DF.Functional=="Sal"] = pd.Series([0]*len(DF.Functional[DF.Functional=="Sal"])).values

DF.FireplaceQu[DF.FireplaceQu=="Ex"]  = pd.Series([5]*len(DF.FireplaceQu[DF.FireplaceQu=="Ex"])).values
DF.FireplaceQu[DF.FireplaceQu=="Gd"]  = pd.Series([4]*len(DF.FireplaceQu[DF.FireplaceQu=="Gd"])).values
DF.FireplaceQu[DF.FireplaceQu=="TA"]  = pd.Series([3]*len(DF.FireplaceQu[DF.FireplaceQu=="TA"])).values
DF.FireplaceQu[DF.FireplaceQu=="Fa"]  = pd.Series([2]*len(DF.FireplaceQu[DF.FireplaceQu=="Fa"])).values
DF.FireplaceQu[DF.FireplaceQu=="Po"]  = pd.Series([1]*len(DF.FireplaceQu[DF.FireplaceQu=="Po"])).values
DF.FireplaceQu[DF.FireplaceQu=="No"]  = pd.Series([0]*len(DF.FireplaceQu[DF.FireplaceQu=="No"])).values


DF.GarageType[DF.GarageType=="BuiltIn"]  = pd.Series([5]*len(DF.GarageType[DF.GarageType=="BuiltIn"])).values
DF.GarageType[DF.GarageType=="Attchd"]  = pd.Series([4]*len(DF.GarageType[DF.GarageType=="Attchd"])).values
DF.GarageType[DF.GarageType=="2Types"]  = pd.Series([3]*len(DF.GarageType[DF.GarageType=="2Types"])).values
DF.GarageType[DF.GarageType=="Basement"]  = pd.Series([3]*len(DF.GarageType[DF.GarageType=="Basement"])).values
DF.GarageType[DF.GarageType=="Detchd"]  = pd.Series([2]*len(DF.GarageType[DF.GarageType=="Detchd"])).values
DF.GarageType[DF.GarageType=="CarPort"]  = pd.Series([1]*len(DF.GarageType[DF.GarageType=="CarPort"])).values
DF.GarageType.fillna(0, inplace=True)
# Jerry's add
DF.GarageType[DF.GarageType=="Basment"]  = pd.Series([3]*len(DF.GarageType[DF.GarageType=="Basment"])).values


DF.GarageFinish[DF.GarageFinish=="Fin"]  = pd.Series([3]*len(DF.GarageFinish[DF.GarageFinish=="Fin"])).values
DF.GarageFinish[DF.GarageFinish=="RFn"]  = pd.Series([2]*len(DF.GarageFinish[DF.GarageFinish=="RFn"])).values
DF.GarageFinish[DF.GarageFinish=="Unf"]  = pd.Series([1]*len(DF.GarageFinish[DF.GarageFinish=="Unf"])).values
DF.GarageFinish.fillna(0, inplace=True)

DF.GarageQual[DF.GarageQual=="Ex"]  = pd.Series([5]*len(DF.GarageQual[DF.GarageQual=="Ex"])).values
DF.GarageQual[DF.GarageQual=="Gd"]  = pd.Series([4]*len(DF.GarageQual[DF.GarageQual=="Gd"])).values
DF.GarageQual[DF.GarageQual=="TA"]  = pd.Series([3]*len(DF.GarageQual[DF.GarageQual=="TA"])).values
DF.GarageQual[DF.GarageQual=="Fa"]  = pd.Series([2]*len(DF.GarageQual[DF.GarageQual=="Fa"])).values
DF.GarageQual[DF.GarageQual=="Po"]  = pd.Series([1]*len(DF.GarageQual[DF.GarageQual=="Po"])).values
DF.GarageQual.fillna(0, inplace=True)

DF.GarageCond[DF.GarageCond=="Ex"]  = pd.Series([5]*len(DF.GarageCond[DF.GarageCond=="Ex"])).values
DF.GarageCond[DF.GarageCond=="Gd"]  = pd.Series([4]*len(DF.GarageCond[DF.GarageCond=="Gd"])).values
DF.GarageCond[DF.GarageCond=="TA"]  = pd.Series([3]*len(DF.GarageCond[DF.GarageCond=="TA"])).values
DF.GarageCond[DF.GarageCond=="Fa"]  = pd.Series([2]*len(DF.GarageCond[DF.GarageCond=="Fa"])).values
DF.GarageCond[DF.GarageCond=="Po"]  = pd.Series([1]*len(DF.GarageCond[DF.GarageCond=="Po"])).values
DF.GarageCond.fillna(0, inplace=True)

DF.PavedDrive[DF.PavedDrive=="Y"]  = pd.Series([2]*len(DF.PavedDrive[DF.PavedDrive=="Y"])).values
DF.PavedDrive[DF.PavedDrive=="P"]  = pd.Series([1]*len(DF.PavedDrive[DF.PavedDrive=="P"])).values
DF.PavedDrive[DF.PavedDrive=="N"]  = pd.Series([0]*len(DF.PavedDrive[DF.PavedDrive=="N"])).values

DF.PoolQC[DF.PoolQC=="Ex"] = pd.Series([4]*len(DF.PoolQC[DF.PoolQC=="Ex"])).values
DF.PoolQC[DF.PoolQC=="Gd"]  = pd.Series([3]*len(DF.PoolQC[DF.PoolQC=="Gd"])).values
DF.PoolQC[DF.PoolQC=="TA"]  = pd.Series([2]*len(DF.PoolQC[DF.PoolQC=="TA"])).values
DF.PoolQC[DF.PoolQC=="Fa"]  = pd.Series([1]*len(DF.PoolQC[DF.PoolQC=="Fa"])).values
DF.PoolQC.fillna(0, inplace=True)

DF.Fence[DF.Fence=="GdPrv"] = pd.Series([4]*len(DF.Fence[DF.Fence=="GdPrv"])).values
DF.Fence[DF.Fence=="MnPrv"]  = pd.Series([3]*len(DF.Fence[DF.Fence=="MnPrv"])).values
DF.Fence[DF.Fence=="GdWo"]  = pd.Series([2]*len(DF.Fence[DF.Fence=="GdWo"])).values
DF.Fence[DF.Fence=="MnWw"]  = pd.Series([1]*len(DF.Fence[DF.Fence=="MnWw"])).values
DF.Fence.fillna(0, inplace=True)
# Out:
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\ipykernel_launcher.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
DF.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450      2     0        4
# 1   2          20       RL         80.0     9600      2     0        4
# 2   3          60       RL         68.0    11250      2     0        3
# 3   4          70       RL         60.0     9550      2     0        3
# 4   5          60       RL         84.0    14260      2     0        3
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl         4    ...            0      0     0         NaN       0
# 1         Lvl         4    ...            0      0     0         NaN       0
# 2         Lvl         4    ...            0      0     0         NaN       0
# 3         Lvl         4    ...            0      0     0         NaN       0
# 4         Lvl         4    ...            0      0     0         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ## Missing Value Percentage
#
# This indicates that "FirePlaceQu" and "MiscFeature" have more than 50% missing data point.
#
# I would recommend to exclude these variable for analysis

# %%
L = []
for c in range(DF.shape[1]):
    MP = np.average(pd.isnull(DF.iloc[:,c]))
    ColName = DF.columns[c]
    pair = ( ColName,  MP )
    L = L + [pair]

# %%
MissingPercentage= pd.DataFrame(L)
f, ax = plt.subplots(figsize=(6, 15))
sns.barplot(MissingPercentage.iloc[:,1],MissingPercentage.iloc[:,0] )
ax.set(xlim=(0, 1), ylabel="", xlabel="Missing value percentage")


plt.show()
# Out:
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# ##  Correlation

# %%
corrmat = DF.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()

# %%
# Correlation between SalePrice and other variables
PriceCorr = pd.DataFrame( corrmat['SalePrice'] )
PriceCorr = PriceCorr.sort_values(by= ["SalePrice"], ascending=False)
PriceCorr = PriceCorr.reset_index()


# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))
#sns.set_color_codes("pastel")
sns.barplot(y = "index", x="SalePrice", data=PriceCorr, color="b")

ax.set(xlim=(-1.01, 1.01), ylabel="index", xlabel="Correlation Coefficient for SalePrice")
plt.show()
# Out:
# C:\Users\WeiKuang\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
PriceCorr[PriceCorr.SalePrice > 0.5]
# Out:
#            index  SalePrice
# 0      SalePrice   1.000000
# 1    OverallQual   0.790982
# 2      GrLivArea   0.708624
# 3     GarageCars   0.640409
# 4     GarageArea   0.623431
# 5       BsmtQual   0.622925
# 6    TotalBsmtSF   0.613581
# 7       1stFlrSF   0.605852
# 8       FullBath   0.560664
# 9   GarageFinish   0.549247
# 10  TotRmsAbvGrd   0.533723
# 11     YearBuilt   0.522897
# 12  YearRemodAdd   0.507101

# %% [markdown]
# ## Select the categorical data

# %%
Cate_Var_idx = DF.columns[ DF.dtypes == np.object ]
Cate_Var_idx = list (Cate_Var_idx)
Cate_Var_idx
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'PavedDrive',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
print (len(Cate_Var_idx))
# Out:
# 33

# %% [markdown]
# Is there a nan/ missing value in the categorical data?
# ANS: Yes.
#
# ['MasVnrType', 'Electrical', 'FireplaceQu', 'MiscFeature'] these categorical data have missing value
#
# 'FireplaceQu', 'MiscFeature' have more than 50% missing value, so they are removed from analysis

# %%
L= []
for i in Cate_Var_idx:
    missing_count = sum(DF[i].isnull() )
    if missing_count > 0:
        entry = [i, missing_count]
        L=L+[entry]
L
# Out:
# [['MasVnrType', 8],
#  ['Electrical', 1],
#  ['FireplaceQu', 690],
#  ['MiscFeature', 1406]]

# %% [markdown]
# I will use the major group to fill the missing value for that categorical variable.
#
# First, let's figure out what is the major group under that variable

# %%
DF.groupby(["MasVnrType"]).size().reset_index(name='counts')
# major gorup is None
# Out:
#   MasVnrType  counts
# 0     BrkCmn      15
# 1    BrkFace     445
# 2       None     864
# 3      Stone     128

# %%
DF.MasVnrType.fillna("None", inplace=True)

# %%
DF.groupby(['Electrical']).size().reset_index(name='counts')
# major gourp is "SBrkr"
# Out:
#   Electrical  counts
# 0      FuseA      94
# 1      FuseF      27
# 2      FuseP       3
# 3        Mix       1
# 4      SBrkr    1334

# %%
DF.Electrical.fillna("SBrkr", inplace=True)

# %% [markdown]
# ## Kruskal-Wallis H Test

# %%
from scipy.stats import kruskal
# Reference https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/

# %%
DF.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450      2     0        4
# 1   2          20       RL         80.0     9600      2     0        4
# 2   3          60       RL         68.0    11250      2     0        3
# 3   4          70       RL         60.0     9550      2     0        3
# 4   5          60       RL         84.0    14260      2     0        3
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl         4    ...            0      0     0         NaN       0
# 1         Lvl         4    ...            0      0     0         NaN       0
# 2         Lvl         4    ...            0      0     0         NaN       0
# 3         Lvl         4    ...            0      0     0         NaN       0
# 4         Lvl         4    ...            0      0     0         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
DF.iloc[0:3,0:10]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450      2     0        4
# 1   2          20       RL         80.0     9600      2     0        4
# 2   3          60       RL         68.0    11250      2     0        3
#
#   LandContour Utilities
# 0         Lvl         4
# 1         Lvl         4
# 2         Lvl         4

# %%
DF.iloc[0:3,11:20]
# Out:
#   LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0       Gtl      CollgCr       Norm       Norm     1Fam          2
# 1       Gtl      Veenker      Feedr       Norm     1Fam          1
# 2       Gtl      CollgCr       Norm       Norm     1Fam          2
#
#    OverallQual  OverallCond  YearBuilt
# 0            7            5       2003
# 1            6            8       1976
# 2            7            5       2001

# %%
DF.iloc[0:3,21:30]
# Out:
#   RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# 0     Gable  CompShg     VinylSd     VinylSd    BrkFace       196.0         3
# 1     Gable  CompShg     MetalSd     MetalSd       None         0.0         2
# 2     Gable  CompShg     VinylSd     VinylSd    BrkFace       162.0         3
#
#   ExterCond Foundation
# 0         3      PConc
# 1         3     CBlock
# 2         3      PConc

# %%
DF.iloc[0:3,31:40]
# Out:
#    BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  \
# 0         3             1             6         706             1           0
# 1         3             4             5         978             1           0
# 2         3             2             6         486             1           0
#
#    BsmtUnfSF  TotalBsmtSF Heating
# 0        150          856    GasA
# 1        284         1262    GasA
# 2        434          920    GasA

# %%
DF.iloc[0:3,41:50]
# Out:
#   CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0          Y      SBrkr       856       854             0       1710
# 1          Y      SBrkr      1262         0             0       1262
# 2          Y      SBrkr       920       866             0       1786
#
#    BsmtFullBath  BsmtHalfBath  FullBath
# 0             1             0         2
# 1             0             1         2
# 2             1             0         2

# %%
DF.iloc[0:3,51:60]
# Out:
#    BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# 0             3             1           4             8          7
# 1             3             1           3             6          7
# 2             3             1           4             6          7
#
#    Fireplaces FireplaceQu GarageType  GarageYrBlt
# 0           0         NaN          4       2003.0
# 1           1           3          4       1976.0
# 2           1           3          4       2001.0

# %%
DF.iloc[0:3,61:70]
# Out:
#    GarageCars  GarageArea  GarageQual  GarageCond PavedDrive  WoodDeckSF  \
# 0           2         548           3           3          2           0
# 1           2         460           3           3          2         298
# 2           2         608           3           3          2           0
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch
# 0           61              0          0
# 1            0              0          0
# 2           42              0          0

# %%
DF.iloc[0:3,71:80]
# Out:
#    PoolArea  PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0         0       0      0         NaN        0       2    2008       WD
# 1         0       0      0         NaN        0       5    2007       WD
# 2         0       0      0         NaN        0       9    2008       WD
#
#   SaleCondition
# 0        Normal
# 1        Normal
# 2        Normal

# %%
DF.iloc[0:3,71:81]
# Out:
#    PoolArea  PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0         0       0      0         NaN        0       2    2008       WD
# 1         0       0      0         NaN        0       5    2007       WD
# 2         0       0      0         NaN        0       9    2008       WD
#
#   SaleCondition  SalePrice
# 0        Normal     208500
# 1        Normal     181500
# 2        Normal     223500

# %% [markdown]
# Categorical data list:
# MSZoning
# Street
# Alley

# %% [markdown]
# ### MSZoning  Note: Price is  Not Significant diff in MSZoning by  kruskal wallis test

# %%
# Remove the useless categorical variable
Cate_Var_idx2= Cate_Var_idx.copy()
Cate_Var_idx2.remove("FireplaceQu")
Cate_Var_idx2.remove("MiscFeature")
Cate_Var_idx2
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
# Display how many gourps under categorical data
L2 = []
for i in Cate_Var_idx2:
    g = len(np.unique(DF[i]))
    L2 = L2 + [g]
    
np.unique(L2)
# Out:
# array([ 2,  3,  4,  5,  6,  7,  8,  9, 15, 16, 25])

# %%
def kruskal_141C (df):
    groups = np.unique(df)
    N = len(groups)
    
    # create sub dataset
    d_list = []
    for i in range(N):
        d = Y[df== groups[i]] 
        d_list = d_list + [d]
        
    # kruskal wallis test depending on the levels of the target variable
    if N == 2:
        stat, p = kruskal(d_list[0], d_list[1])
        
    elif N == 3:
        stat, p = kruskal(d_list[0], d_list[1], d_list[2])
        
    elif N == 4:
        stat, p = kruskal(d_list[0], d_list[1], d_list[2], d_list[3])
        
    elif N == 5:
        stat, p = kruskal(d_list[0], d_list[1], d_list[2], d_list[3], d_list[4])
        
    elif N == 6:
        stat, p = kruskal(d_list[0], d_list[1], d_list[2], d_list[3], d_list[4], d_list[5])
    
    elif N == 7:
        stat, p = kruskal(d_list[0], d_list[1], d_list[2], d_list[3], d_list[4], d_list[5], d_list[6])
        
    elif N == 8:
        stat, p = kruskal(d_list[0], d_list[1], d_list[2], d_list[3], d_list[4], d_list[5], d_list[6], d_list[7])    
    
    elif N == 9:
        stat, p = kruskal(d_list[0], d_list[1], d_list[2], d_list[3], d_list[4], d_list[5], d_list[6], d_list[7], d_list[8])
    
    elif N == 15:
        stat, p = kruskal(d_list[0], d_list[1], d_list[2], d_list[3], d_list[4], d_list[5], d_list[6], d_list[9], d_list[10], d_list[11], d_list[12], d_list[13], d_list[14])
    
    elif N == 16:
        stat, p = kruskal(d_list[0], d_list[1], d_list[2], d_list[3], d_list[4], d_list[5], d_list[6], d_list[9], d_list[10], d_list[11], d_list[12], d_list[13], d_list[14], d_list[15])
    
    elif N == 25:
        stat, p = kruskal(d_list[0], d_list[1], d_list[2], d_list[3], d_list[4], d_list[5], d_list[6], d_list[9], d_list[10], d_list[11], d_list[12], d_list[13], d_list[14], d_list[15], d_list[16], d_list[17], d_list[18], d_list[19], d_list[20], d_list[21], d_list[22], d_list[23], d_list[24])
    
    result = p
    
    return( result)

# %%
# function test
kruskal_141C(DF["MSZoning"])
# Out:
# 3.0807239995999556e-57

# %%
kruskal_141C(DF["Street"])
# Out:
# 0.08012555757743882

# %%
# for loop to run  kruskal on each categorical data 
p_L = []
for i in Cate_Var_idx2:
    p = kruskal_141C(DF[i])
    p_L= p_L+ [p]
    
#p_L

# %%
d = {'Categorical_Var': Cate_Var_idx2, 'kruskal_test_pvale': p_L}
Kruskal_Result = pd.DataFrame(data= d)
Kruskal_Result
# Out:
#    Categorical_Var  kruskal_test_pvale
# 0         MSZoning        3.080724e-57
# 1           Street        8.012556e-02
# 2            Alley        1.184056e-10
# 3         LotShape        1.640323e-32
# 4      LandContour        1.047923e-07
# 5        Utilities        5.233080e-01
# 6        LotConfig        3.297912e-07
# 7        LandSlope        1.395380e-01
# 8     Neighborhood       3.536389e-148
# 9       Condition1        6.492600e-13
# 10      Condition2        1.303159e-02
# 11        BldgType        2.500858e-14
# 12      HouseStyle        2.261296e-35
# 13       RoofStyle        1.580733e-07
# 14        RoofMatl        8.597464e-03
# 15     Exterior1st        2.751581e-45
# 16     Exterior2nd        8.677742e-42
# 17      MasVnrType        2.058731e-58
# 18       ExterQual       8.180798e-148
# 19       ExterCond        1.832365e-09
# 20      Foundation       2.169096e-103
# 21         Heating        3.331280e-06
# 22       HeatingQC        6.036449e-76
# 23      CentralAir        5.319642e-33
# 24      Electrical        1.850352e-27
# 25     KitchenQual       4.720113e-143
# 26      Functional        1.274180e-05
# 27      GarageType       6.978863e-113
# 28      PavedDrive        7.012268e-26
# 29        SaleType        9.119744e-30
# 30   SaleCondition        1.663313e-34

# %%
len( Kruskal_Result [Kruskal_Result.kruskal_test_pvale < 0.01 ] )
# there are 27 Categorical vairaibles associated with SalePrice
# Out:
# 27

# %%
# These informative categorical variables are:
D1 = Kruskal_Result[Kruskal_Result.kruskal_test_pvale < 0.01 ]
D1.iloc[:,0]
# Out:
# 0          MSZoning
# 2             Alley
# 3          LotShape
# 4       LandContour
# 6         LotConfig
# 8      Neighborhood
# 9        Condition1
# 11         BldgType
# 12       HouseStyle
# 13        RoofStyle
# 14         RoofMatl
# 15      Exterior1st
# 16      Exterior2nd
# 17       MasVnrType
# 18        ExterQual
# 19        ExterCond
# 20       Foundation
# 21          Heating
# 22        HeatingQC
# 23       CentralAir
# 24       Electrical
# 25      KitchenQual
# 26       Functional
# 27       GarageType
# 28       PavedDrive
# 29         SaleType
# 30    SaleCondition
# Name: Categorical_Var, dtype: object

# %% [markdown]
# ### testing zone

# %%
Y = DF.SalePrice
df = DF.MSZoning

grps = np.unique(df)
N = len(grps )

# %%
# create sub dataset
d_list = []
for i in range(N):
    d = Y[df== grps[i]] 
    d_list = d_list + [d]

if N == 5:
    stat, p = kruskal(d_list[0], d_list[1], d_list[2], d_list[3], d_list[4])

# %%
L =[]
#DF.shape[1]
for i in range(26):
    if type(DF.iloc[:,i][0]) == np.str:
        g = len(np.unique(DF.iloc[:,i]))
    else:
        g = 0
    L = L + [g]
